# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
read csv.
# Sütun grafiğini oluşturma
plt.bar(yillar, erkek_oranlari, color='blue', label='Erkek Yöneticiler')
plt.bar(yillar, kadin_oranlari, color='pink', bottom=erkek_oranlari, label='Kadın Yöneticiler')

# Eksen ve başlık ayarları
plt.xlabel('Yıl')
plt.ylabel('Yönetici Oranı')
plt.title('Cinsiyete Göre Yönetici Oranları')
plt.xticks(yillar)  # X ekseni değerlerini yıllar olarak ayarlar
plt.legend()  # Grafikteki renklerin neyi temsil ettiğini gösteren bir açıklama ekler

# Grafiği gösterme
plt.show()
